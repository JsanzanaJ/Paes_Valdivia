# %%
import pandas as pd

# %%
datar = pd.read_csv('../data/processed/paes_valdivia.csv')
datar.head(15)

# Limpiar RBD: quedarse solo con lo anterior al "-"
datar["rbd"] = (
    datar["rbd"]
    .astype(str)
    .str.split("-")
    .str[0]
)

# Guardar archivo limpio
datar.to_csv("../data/processed/paes_valdivia_limpio.csv", index=False)
datar
# Out:
#      anio                                   establecimiento   rbd  \
# 0    2024  Liceo Politecnico Benjamin Vicuna Mackenna\nRama  6757
# 1    2024  Liceo Politecnico Benjamin Vicuna Mackenna\nRama  6757
# 2    2024  Liceo Politecnico Benjamin Vicuna Mackenna\nRama  6757
# 3    2024  Liceo Politecnico Benjamin Vicuna Mackenna\nRama  6757
# 4    2024  Liceo Politecnico Benjamin Vicuna Mackenna\nRama  6757
# ..    ...                                               ...   ...
# 313  2026           Instituto Aleman Carlos Anwandter\nRama  6844
# 314  2026           Instituto Aleman Carlos Anwandter\nRama  6844
# 315  2026           Instituto Aleman Carlos Anwandter\nRama  6844
# 316  2026           Instituto Aleman Carlos Anwandter\nRama  6844
# 317  2026           Instituto Aleman Carlos Anwandter\nRama  6844
#
#           prueba  promedio
# 0       Lenguaje     378.0
# 1             M1     436.0
# 2             M2     290.0
# 3       Historia       0.0
# 4       Ciencias       0.0
# ..           ...       ...
# 313           M1     816.5
# 314           M2     513.4
# 315     Historia     578.4
# 316     Ciencias     612.2
# 317  Obligatoria     770.2
#
# [318 rows x 5 columns]

# %%
datac = pd.read_csv('../data/colegios/establecimientos_mineduc.csv', sep=';')
datac
datac_subset = datac[["RBD", "DGV_RBD", "NOM_RBD", "NOM_COM_RBD", "LATITUD", "LONGITUD"]]
datac_subset.head(12)
# Out:
#     RBD  DGV_RBD                                            NOM_RBD  \
# 0     1        9                            LICEO POLITECNICO ARICA
# 1     2        7                          PARVULARIO LAS ESPIGUITAS
# 2     3        5                ESC. PEDRO VICENTE GUTIERREZ TORRES
# 3     4        3                          LICEO OCTAVIO PALMA PEREZ
# 4     5        1                           JOVINA NARANJO FERNANDEZ
# 5     7        8  L. POLI. BICENTENARIO DE EXCELENCIA ANTONIO VA...
# 6     8        6                      COLEGIO EDUARDO FREI MONTALVA
# 7     9        4                        ESCUELA REPUBLICA DE ISRAEL
# 8    10        8                       ESCUELA REPUBLICA DE FRANCIA
# 9    11        6                    ESC. GRAL. PEDRO LAGOS MARCHANT
# 10   12        4                   ESCUELA GRAL JOSE MIGUEL CARRERA
# 11   13        2                   ESCUELA MANUEL RODRIGUEZ ERDOYZA
#
#    NOM_COM_RBD       LATITUD      LONGITUD
# 0        ARICA      -18,4872    -70,295212
# 1        ARICA  -18,46986198  -70,30275726
# 2        ARICA  -18,50358009  -70,26082611
# 3        ARICA    -18,474239    -70,308273
# 4        ARICA      -18,4769    -70,313454
# 5        ARICA    -18,476151    -70,288368
# 6        ARICA    -18,482491    -70,317581
# 7        ARICA    -18,486691     -70,30452
# 8        ARICA    -18,474369    -70,309036
# 9        ARICA    -18,491011    -70,311577
# 10       ARICA     -18,49193    -70,293968
# 11       ARICA     -18,48134    -70,285347

# %%
# Filtrar filas por valor exacto
valdivia = datac_subset[datac_subset["NOM_COM_RBD"] == "VALDIVIA"]
valdivia
# Out:
#          RBD  DGV_RBD                                  NOM_RBD NOM_COM_RBD  \
# 5560    6751        2          INSTITUTO COMERCIAL DE VALDIVIA    VALDIVIA
# 5561    6752        0                   LICEO TECNICO VALDIVIA    VALDIVIA
# 5562    6753        9              LICEO SANTA MARIA LA BLANCA    VALDIVIA
# 5563    6754        7              LICEO ARMANDO ROBLES RIVERA    VALDIVIA
# 5564    6755        5                LICEO INDUSTRIAL VALDIVIA    VALDIVIA
# ...      ...      ...                                      ...         ...
# 16566  42067        0                            INDEPENDENCIA    VALDIVIA
# 16568  42072        7       JARDIN INFANTIL ESTRELLITA NUESTRA    VALDIVIA
# 16647  42202        9                           ALTO GUACAMAYO    VALDIVIA
# 16667  42248        7  SALA CUNA Y JARDIN INFANTIL MIS HUELLAS    VALDIVIA
# 16669  42250        9               CLUB DEL BOSQUE VALDIVIANO    VALDIVIA
#
#             LATITUD      LONGITUD
# 5560     -39,817619    -73,246964
# 5561      -39,82925    -73,221237
# 5562      -39,81601    -73,240768
# 5563      -39,81567    -73,242622
# 5564     -39,831871    -73,220757
# ...             ...           ...
# 16566
# 16568
# 16647
# 16667
# 16669  -39,80966719  -73,25952667
#
# [172 rows x 6 columns]

# %%
paes = pd.read_csv("../data/processed/paes_valdivia_limpio.csv")
mineduc = pd.read_csv("../data/colegios/establecimientos_mineduc.csv", sep=';')

print(paes["rbd"].head())
print(mineduc["RBD"].head())

print(paes["rbd"].dtype, mineduc["RBD"].dtype)
# Out:
# 0    6757
# 1    6757
# 2    6757
# 3    6757
# 4    6757
# Name: rbd, dtype: int64
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: RBD, dtype: int64
# int64 int64

# %%
paes["rbd"] = paes["rbd"].astype(str).str.strip()
mineduc["rbd"] = mineduc["RBD"].astype(str).str.strip()

# %%
paes_geo = paes.merge(
    mineduc[["rbd", "LATITUD", "LONGITUD"]],
    on="rbd",
    how="left"
)

sin_coord = paes_geo["LATITUD"].isna().sum()

print(f"Colegios sin coordenadas: {sin_coord}")


paes_geo.to_csv(
    "../data/processed/paes_valdivia_geo.csv",
    index=False
)
# Out:
# Colegios sin coordenadas: 0

# %%
paes_geo
# Out:
#      anio                                   establecimiento   rbd  \
# 0    2024  Liceo Politecnico Benjamin Vicuna Mackenna\nRama  6757
# 1    2024  Liceo Politecnico Benjamin Vicuna Mackenna\nRama  6757
# 2    2024  Liceo Politecnico Benjamin Vicuna Mackenna\nRama  6757
# 3    2024  Liceo Politecnico Benjamin Vicuna Mackenna\nRama  6757
# 4    2024  Liceo Politecnico Benjamin Vicuna Mackenna\nRama  6757
# ..    ...                                               ...   ...
# 313  2026           Instituto Aleman Carlos Anwandter\nRama  6844
# 314  2026           Instituto Aleman Carlos Anwandter\nRama  6844
# 315  2026           Instituto Aleman Carlos Anwandter\nRama  6844
# 316  2026           Instituto Aleman Carlos Anwandter\nRama  6844
# 317  2026           Instituto Aleman Carlos Anwandter\nRama  6844
#
#           prueba  promedio     LATITUD    LONGITUD
# 0       Lenguaje     378.0  -39,826889  -73,206703
# 1             M1     436.0  -39,826889  -73,206703
# 2             M2     290.0  -39,826889  -73,206703
# 3       Historia       0.0  -39,826889  -73,206703
# 4       Ciencias       0.0  -39,826889  -73,206703
# ..           ...       ...         ...         ...
# 313           M1     816.5  -39,811772   -73,25277
# 314           M2     513.4  -39,811772   -73,25277
# 315     Historia     578.4  -39,811772   -73,25277
# 316     Ciencias     612.2  -39,811772   -73,25277
# 317  Obligatoria     770.2  -39,811772   -73,25277
#
# [318 rows x 7 columns]

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from pathlib import Path

# =========================
# RUTAS
# =========================
INPUT = Path("../data/processed/paes_valdivia_geo.csv")
OUTPUT = Path("../data/processed/paes_valdivia.geojson")



# =========================
# CARGA
# =========================
df = pd.read_csv(INPUT)

# =========================
# LIMPIEZA COORDENADAS
# =========================
df["LATITUD"] = (
    df["LATITUD"]
    .astype(str)
    .str.replace(",", ".", regex=False)
    .astype(float)
)

df["LONGITUD"] = (
    df["LONGITUD"]
    .astype(str)
    .str.replace(",", ".", regex=False)
    .astype(float)
)


# Seguridad básica
df = df.dropna(subset=["LATITUD", "LONGITUD"])

# =========================
# CREAR GEOMETRÍA
# =========================
geometry = [
    Point(xy) for xy in zip(df["LONGITUD"], df["LATITUD"])
]

gdf = gpd.GeoDataFrame(
    df,
    geometry=geometry,
    crs="EPSG:4326"
)

# =========================
# EXPORTAR A GEOJSON
# =========================
gdf.to_file(
    OUTPUT,
    driver="GeoJSON",
    encoding="utf-8"
)

print("✅ GeoJSON creado correctamente")
print(f"📍 Archivo: {OUTPUT}")
print(f"🔢 Registros: {len(gdf)}")
# Out:
# ✅ GeoJSON creado correctamente
# 📍 Archivo: ..\data\processed\paes_valdivia.geojson
# 🔢 Registros: 318

# %%
gdf["rbd"] = (
    gdf["rbd"]
    .astype(str)
    .str.split("-")
    .str[0]
)

# %%
gdf_pivot = gdf.pivot_table(
    index=["rbd", "establecimiento", "geometry"],
    columns="prueba",
    values="promedio",
    aggfunc="mean"
).reset_index()
gdf_pivot
# Out:
# prueba    rbd                                    establecimiento  \
# 0       12185                Colegio Bicentenario Helvecia\nRama
# 1       22014                            Colegio Baquedano\nRama
# 2       22160                   Martin Luther King College\nRama
# 3       22177                     Colegio San Luis De Alba\nRama
# 4       22188        Centro Educacion Adultos Andres Bello\nRama
# 5       22231                          Colegio Domus Mater\nRama
# 6       22351              Instituto Inmaculada Concepcion\nRama
# 7       22374                Instituto Tecnologico Del Sur\nRama
# 8       22388                                     Centro De Educ
# 9       22398                               Colegio Aliwen\nRama
# 10      22415                                               Inst
# 11      22459                       Colegio Laico Valdivia\nRama
# 12      22496               Centro Educacional San Nicolas\nRama
# 13      22516             Instituto Cristiano Gracia Y Paz\nRama
# 14      22540                 Instituto Italia De Valdivia\nRama
# 15      22627                              Hampton College\nRama
# 16      22629                   Colegio Los Conquistadores\nRama
# 17      22633                                          Liceo Tec
# 18      22634               Instituto Principe De Asturias\nRama
# 19      22759                               Master College\nRama
# 20      31010  Liceo Bicentenario Ciudad De Los Rios Valdivi\...
# 21      31012  Instituto Bicentenario De Excelencia Chile Asi...
# 22      41712                   Colegio Comunitario Enlace\nRama
# 23       6751              Instituto Comercial De Valdivia\nRama
# 24       6752                       Liceo Tecnico Valdivia\nRama
# 25       6753                  Liceo Santa Maria La Blanca\nRama
# 26       6754                  Liceo Armando Robles Rivera\nRama
# 27       6755                    Liceo Industrial Valdivia\nRama
# 28       6757  Instituto De Recursos Renovables Y Tecnología ...
# 29       6757   Liceo Politecnico Benjamin Vicuna Mackenna\nRama
# 30       6766        Colegio Teniente Hernan Merino Correa\nRama
# 31       6770  Colegio Bicentenario De Musica Juan Sebastian ...
# 32       6787                                        Centro Educ
# 33       6791                 Escuela De Niebla Juan Bosch\nRama
# 34       6826              Colegio Santa Marta De Valdivia\nRama
# 35       6828                              Colegio Austral\nRama
# 36       6829                          Instituto Salesiano\nRama
# 37       6830            Colegio Nuestra Senora Del Carmen\nRama
# 38       6832                    Colegio Maria Auxiliadora\nRama
# 39       6834                Colegio Metodista La Trinidad\nRama
# 40       6835               Colegio Adventista De Valdivia\nRama
# 41       6836                    Colegio Alonso De Ercilla\nRama
# 42       6843                       Colegio Windsor School\nRama
# 43       6844            Instituto Aleman Carlos Anwandter\nRama
#
# prueba                     geometry  Ciencias    Historia    Lenguaje  \
# 0       POINT (-73.21696 -39.84378)    415.20  454.250000  543.300000
# 1       POINT (-73.23893 -39.82272)    441.90  507.300000  582.800000
# 2       POINT (-73.24035 -39.83623)    455.70  456.300000  575.000000
# 3       POINT (-73.28399 -39.84522)    596.10  620.100000  733.800000
# 4       POINT (-73.23983 -39.81742)    426.00  432.800000  503.100000
# 5       POINT (-73.24646 -39.82877)    523.90  623.300000  697.100000
# 6       POINT (-73.24644 -39.81818)    538.20  574.000000  690.900000
# 7       POINT (-73.21410 -39.82331)    359.05  386.750000  442.800000
# 8       POINT (-73.24007 -39.81233)    395.60  452.900000  569.300000
# 9       POINT (-73.25021 -39.82786)    467.70  519.100000  629.400000
# 10      POINT (-73.24611 -39.82596)    270.40  455.833333  534.833333
# 11      POINT (-73.23935 -39.82761)    431.40  549.100000  638.400000
# 12      POINT (-73.22917 -39.85592)    365.45  231.500000  503.450000
# 13      POINT (-73.24846 -39.82019)    437.60  497.600000  599.300000
# 14      POINT (-73.23103 -39.83834)    423.60  492.400000  603.800000
# 15      POINT (-73.21424 -39.79970)    465.80  540.500000  635.800000
# 16      POINT (-73.25677 -39.85322)    495.10  516.600000  632.500000
# 17      POINT (-73.19952 -39.84661)    373.60  464.850000  472.600000
# 18      POINT (-73.24363 -39.82907)    448.10  501.500000  614.700000
# 19      POINT (-73.21869 -39.80384)    488.10  487.600000  599.900000
# 20      POINT (-73.23488 -39.83093)    452.60  496.000000  626.100000
# 21      POINT (-73.21227 -39.85233)    412.00  458.200000  546.900000
# 22      POINT (-72.72350 -38.79080)      0.00  406.000000  373.000000
# 23      POINT (-73.24696 -39.81762)    423.70  470.066667  545.566667
# 24      POINT (-73.22124 -39.82925)    403.40  419.300000  524.300000
# 25      POINT (-73.24077 -39.81601)    431.50  463.700000  582.900000
# 26      POINT (-73.24262 -39.81567)    440.30  499.500000  589.000000
# 27      POINT (-73.22076 -39.83187)    385.00  428.000000  512.100000
# 28      POINT (-73.20670 -39.82689)    389.50  434.750000  545.750000
# 29      POINT (-73.20670 -39.82689)      0.00    0.000000  378.000000
# 30      POINT (-73.21548 -39.83773)    405.10  463.400000  561.600000
# 31      POINT (-73.22173 -39.83084)    482.40  528.200000  662.600000
# 32      POINT (-73.22041 -39.83191)    382.20  416.600000  502.600000
# 33      POINT (-73.39899 -39.87306)    409.00    0.000000  455.000000
# 34      POINT (-73.21010 -39.82829)    449.80  516.200000  614.900000
# 35      POINT (-73.24120 -39.82061)    464.20  544.100000  626.600000
# 36      POINT (-73.23791 -39.81499)    511.60  558.200000  649.300000
# 37      POINT (-73.23019 -39.82616)    446.50  505.400000  611.000000
# 38      POINT (-73.23385 -39.81713)    491.00  543.700000  652.900000
# 39      POINT (-73.20555 -39.82826)    458.30  695.000000  594.800000
# 40      POINT (-73.22164 -39.83087)    483.40  482.900000  603.400000
# 41      POINT (-73.24898 -39.81975)    486.50  538.800000  627.000000
# 42      POINT (-73.24143 -39.83337)    639.70  610.700000  729.900000
# 43      POINT (-73.25277 -39.81177)    612.20  578.400000  724.700000
#
# prueba          M1          M2  Obligatoria
# 0       529.700000  211.200000   541.350000
# 1       593.300000  375.900000   590.300000
# 2       630.200000  425.400000   604.100000
# 3       856.700000  521.300000   795.200000
# 4       485.600000  409.000000   494.400000
# 5       734.600000  459.100000   715.800000
# 6       730.900000  511.900000   710.900000
# 7       477.000000  371.500000   453.750000
# 8       555.600000  326.500000   565.600000
# 9       625.600000  442.300000   627.500000
# 10      552.300000  140.166667   543.133333
# 11      635.900000  409.500000   637.100000
# 12      523.600000  417.500000   513.500000
# 13      585.000000  402.700000   592.200000
# 14      593.500000  399.500000   603.000000
# 15      657.300000  435.300000   646.500000
# 16      652.800000  410.100000   642.600000
# 17      457.850000    0.000000   465.250000
# 18      610.600000  425.400000   612.700000
# 19      634.500000  403.400000   620.300000
# 20      623.700000  435.300000   624.900000
# 21      547.800000  349.700000   547.300000
# 22      462.000000    0.000000   417.500000
# 23      557.066667  395.066667   551.366667
# 24      518.100000  389.700000   522.800000
# 25      588.300000  396.800000   587.300000
# 26      590.900000  416.000000   591.700000
# 27      580.200000  389.000000   548.300000
# 28      557.500000  387.500000   551.650000
# 29      436.000000  290.000000   407.000000
# 30      550.100000  372.100000   555.800000
# 31      668.300000  443.400000   666.700000
# 32      521.400000  487.500000   512.000000
# 33      609.000000  382.000000   532.000000
# 34      616.100000  415.300000   617.200000
# 35      645.600000  374.200000   636.100000
# 36      717.500000  451.700000   683.400000
# 37      580.500000  415.300000   596.800000
# 38      647.300000  396.200000   650.100000
# 39      579.400000  366.000000   587.100000
# 40      619.900000  411.600000   613.700000
# 41      652.900000  460.400000   642.000000
# 42      805.300000  584.400000   767.600000
# 43      816.500000  513.400000   770.200000

# %%
import geopandas as gpd

gdf_colegios = gpd.GeoDataFrame(
    gdf_pivot,
    geometry="geometry",
    crs="EPSG:4326"
)

# %%
print("Colegios únicos:", gdf_colegios["rbd"].nunique())
print("Filas totales:", len(gdf_colegios))
# Out:
# Colegios únicos: 43
# Filas totales: 44

# %%
gdf_colegios.to_file(
    "../data/processed/colegios_paes_valdivia.geojson",
    driver="GeoJSON"
)

print("✅ GeoJSON consolidado por RBD creado correctamente")
# Out:
# ✅ GeoJSON consolidado por RBD creado correctamente
